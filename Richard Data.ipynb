# %%
from project.store import fread
from project.echonest import CachedData, Artist
# Read in file
a_dict = fread("C:/Users/Richard/Bayesian-Asians-Project/data/RichardArtist.pkl")
# Generate a cached data object
cd = CachedData(a_dict)
# Find out all artist info from these.
Artist.from_cached(cd)
# Out:
#  Finished with 0.0000 Percent!
#  Finished with 0.0033 Percent!
#  Finished with 0.0066 Percent!
#  Finished with 0.0099 Percent!
#  Finished with 0.0132 Percent!
#  Finished with 0.0166 Percent!
#  Finished with 0.0199 Percent!
#  Finished with 0.0232 Percent!
#  Finished with 0.0265 Percent!
#  Finished with 0.0298 Percent!
#  Finished with 0.0331 Percent!
#  Finished with 0.0364 Percent!
#  Finished with 0.0397 Percent!
#  Finished with 0.0430 Percent!
#  Finished with 0.0464 Percent!
#  Finished with 0.0497 Percent!
#  Finished with 0.0530 Percent!
#  Finished with 0.0563 Percent!
#  Finished with 0.0596 Percent!
#  Finished with 0.0629 Percent!
#  Finished with 0.0662 Percent!
#  Finished with 0.0695 Percent!
#  Finished with 0.0728 Percent!
#  Finished with 0.0762 Percent!
#  Finished with 0.0795 Percent!
#  Finished with 0.0828 Percent!
#  Finished with 0.0861 Percent!
#  Finished with 0.0894 Percent!
#  Finished with 0.0927 Percent!
#  Finished with 0.0960 Percent!
# ...

# %%
from project.store import fwrite

# %%
fwrite(cd, "C:/Users/Richard/Downloads/richarddatacd.txt")
